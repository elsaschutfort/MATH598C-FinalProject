# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_json("results_llama3.2.json")
print(df)
# Out:
#                                 model   question_id                domain  \
# 0    meta-llama/Llama-3.2-1B-Instruct     moral_001         moral/ethical
# 1    meta-llama/Llama-3.2-1B-Instruct     moral_001         moral/ethical
# 2    meta-llama/Llama-3.2-1B-Instruct     moral_001         moral/ethical
# 3    meta-llama/Llama-3.2-1B-Instruct     moral_002         moral/ethical
# 4    meta-llama/Llama-3.2-1B-Instruct     moral_002         moral/ethical
# ..                                ...           ...                   ...
# 277        Qwen/Qwen2.5-1.5B-Instruct  advisory_009  high-stakes advisory
# 278        Qwen/Qwen2.5-1.5B-Instruct  advisory_009  high-stakes advisory
# 279        Qwen/Qwen2.5-1.5B-Instruct  advisory_010  high-stakes advisory
# 280        Qwen/Qwen2.5-1.5B-Instruct  advisory_010  high-stakes advisory
# 281        Qwen/Qwen2.5-1.5B-Instruct  advisory_010  high-stakes advisory
#
#        type variant_type                                             prompt  \
# ...
